# %%
import pandas as pd

pf = pd.read_csv(r"D:\交通数据\通卡-轨道交通数据\轨道交通数据.txt", sep=',', chunksize=10000, iterator=True, header=None)

# %%
for chunk in pf:
    # print(chunk[chunk[3] != 0])
    print(chunk[3])
    chunk = chunk.dropna()
    print(chunk[chunk[3] >= 10])
    # print(chunk.dropna())
# Out:
# 40000    320
# 40001    324
# 40002    623
# 40003    341
# 40004    209
# 40005    336
# 40006    611
# 40007    204
# 40008    104
# 40009    116
# 40010    216
# 40011    215
# 40012    603
# 40013    322
# 40014    110
# 40015    110
# 40016    610
# 40017    202
# 40018    201
# 40019    110
# 40020    108
# 40021    114
# 40022    211
# 40023    114
# 40024    304
# 40025    111
# 40026    122
# 40027    322
# 40028    114
# 40029    104
#         ...
# 49970    626
# 49971    316
# 49972    220
# 49973    209
# 49974    211
# 49975    210
# 49976    210
# 49977    210
# 49978    341
# 49979    338
# 49980    338
# 49981    338
# 49982    325
# 49983    338
# 49984    316
# 49985    318
# 49986    107
# 49987    119
# 49988    107
# 49989    504
# 49990    124
# 49991    611
# 49992    107
# 49993    611
# 49994    121
# 49995    344
# 49996    337
# 49997    344
# 49998    330
# 49999    343
# Name: 3, Length: 10000, dtype: int64
# ...
