# %%
import pandas as pd

# %%
pf = pd.read_excel(r"C:\Users\Lzumi\AppData\Roaming\Microsoft\Windows\Network Shortcuts\研管（2019）35号  附件1 2019年研究生获得省部级及其以上竞赛获奖情况统计表（电子版）20191217.xlsx")
pf
# Out:
#             附表1：软件工程学院2019年研究生获得省部级及其以上竞赛奖励情况统计表（电子版） Unnamed: 1 Unnamed: 2  \
# 0                                                 ...        NaN        NaN
# 1                                                  序号       竞赛类别         姓名
# 2                                                 NaN        NaN        NaN
# 3                                                   1       学科竞赛         曾梨
# 4                                                   2       学科竞赛         曾梨
# 5                                                   3       学科竞赛         曾梨
# 6                                                   4       学科竞赛         张正
# 7                                                   5       学科竞赛        涂兆昊
# 8                                                   6       素质竞赛        涂兆昊
# 9                                                   7       学科竞赛        安春生
# 10                                                  8       学科竞赛         陈波
# ...

# %%
pf[3:75]
# Out:
#    附表1：软件工程学院2019年研究生获得省部级及其以上竞赛奖励情况统计表（电子版） Unnamed: 1 Unnamed: 2  \
# 3                                          1       学科竞赛         曾梨
# 4                                          2       学科竞赛         曾梨
# 5                                          3       学科竞赛         曾梨
# 6                                          4       学科竞赛         张正
# 7                                          5       学科竞赛        涂兆昊
# 8                                          6       素质竞赛        涂兆昊
# 9                                          7       学科竞赛        安春生
# 10                                         8       学科竞赛         陈波
# 11                                         9       学科竞赛         陈波
# 12                                        10       学科竞赛         董双
# 13                                        11       学科竞赛         董双
# 14                                        12       学科竞赛         何兮
# 15                                        13       学科竞赛        胡新庭
# ...
